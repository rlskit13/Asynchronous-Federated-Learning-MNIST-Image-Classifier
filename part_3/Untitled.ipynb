# %%
import numpy
import pygad.nn
import pandas

# %%
data = numpy.array(pandas.read_csv("Fish.csv"))

# %%
data[:, 2:]
# Out:
# array([[23.2, 25.4, 30.0, 11.52, 4.02],
#        [24.0, 26.3, 31.2, 12.48, 4.3056],
#        [23.9, 26.5, 31.1, 12.3778, 4.6961],
#        [26.3, 29.0, 33.5, 12.73, 4.4555],
#        [26.5, 29.0, 34.0, 12.444, 5.1339999999999995],
#        [26.8, 29.7, 34.7, 13.6024, 4.9274],
#        [26.8, 29.7, 34.5, 14.1795, 5.2785],
#        [27.6, 30.0, 35.0, 12.67, 4.69],
#        [27.6, 30.0, 35.1, 14.0049, 4.8438],
#        [28.5, 30.7, 36.2, 14.2266, 4.9594],
#        [28.4, 31.0, 36.2, 14.2628, 5.1042],
#        [28.7, 31.0, 36.2, 14.3714, 4.8146],
#        [29.1, 31.5, 36.4, 13.7592, 4.368],
#        [29.5, 32.0, 37.3, 13.9129, 5.0728],
#        [29.4, 32.0, 37.2, 14.9544, 5.1708],
#        [29.4, 32.0, 37.2, 15.437999999999999, 5.58],
#        [30.4, 33.0, 38.3, 14.8604, 5.2854],
#        [30.4, 33.0, 38.5, 14.937999999999999, 5.1975],
#        [30.9, 33.5, 38.6, 15.633, 5.1338],
#        [31.0, 33.5, 38.7, 14.4738, 5.7276],
#        [31.3, 34.0, 39.5, 15.1285, 5.5695],
# ...
